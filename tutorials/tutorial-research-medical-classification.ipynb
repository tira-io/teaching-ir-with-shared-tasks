# %% [markdown]
# # Research Oriented Tutorial: Classification of Medical Queries and Documents

# %%
# This is only needed in Google Colab, in the dev container, everything should be installed already
# !pip3 install tira trectools python-terrier

# %%
from tira.third_party_integrations import ensure_pyterrier_is_loaded
from tira.rest_api_client import Client

import pyterrier as pt

ensure_pyterrier_is_loaded()
tira = Client()
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# No settings given in /root/.tira/.tira-settings.json. I will use defaults.

# %%
dataset = pt.get_dataset("irds:clueweb09/en/trec-web-2009")
topics = dataset.get_topics(variant='query')
topics.head(3)
# Out:
#   qid                          query
# 0   1              obama family tree
# 1   2  french lick resort and casino
# 2   3              getting organized

# %%
query_health_classification = tira.pt.transform_queries('ir-benchmarks/fschlatt/average-string', dataset)
query_health_classification(topics).sort_values('mean_health_score', ascending=False)
# Out:
#    qid                            query                             text  \
# 3    4                           toilet                           toilet
# 29  30               diabetes education               diabetes education
# 25  26                 lower heart rate                 lower heart rate
# 33  34                      cell phones                      cell phones
# 2    3                getting organized                getting organized
# 8    9                   used car parts                   used car parts
# 6    7           air travel information           air travel information
# 49  50                         dog heat                         dog heat
# 45  46        alexian brothers hospital        alexian brothers hospital
# 37  38                dogs for adoption                dogs for adoption
# 18  19                      the current                      the current
# 10  11                gmat prep classes                gmat prep classes
# 15  16            arizona game and fish            arizona game and fish
# 0    1                obama family tree                obama family tree
# 43  44         map of the united states         map of the united states
# 32  33               elliptical trainer               elliptical trainer
# 40  41  orange county convention center  orange county convention center
# 14  15                      espn sports                      espn sports
# 1    2    french lick resort and casino    french lick resort and casino
# 41  42                    the music man                    the music man
# 42  43                the secret garden                the secret garden
# 23  24                        diversity                        diversity
# 12  13                              map                              map
# 11  12                              djs                              djs
# 47  48                   wilson antenna                   wilson antenna
# 48  49                    flame designs                    flame designs
# 28  29                       ps 2 games                       ps 2 games
# 17  18        wedding budget calculator        wedding budget calculator
# 44  45                     solar panels                     solar panels
# 9   10                   cheap internet                   cheap internet
# 31  32           website design hosting           website design hosting
# 13  14                        dinosaurs                        dinosaurs
# 35  36                              gps                              gps
# 4    5                 mitchell college                 mitchell college
# 24  25                           euclid                           euclid
# 46  47                  indexed annuity                  indexed annuity
# 21  22                      rick warren                      rick warren
# 38  39                 disneyland hotel                 disneyland hotel
# 39  40                        michworks                        michworks
# 7    8                       appraisals                       appraisals
# 36  37                    pampered chef                    pampered chef
# 34  35                          hoboken                          hoboken
# 30  31                            atari                            atari
# 27  28                         inuyasha                         inuyasha
# 26  27                        starbucks                        starbucks
# 22  23                            yahoo                            yahoo
# 20  21                            volvo                            volvo
# 19  20                         defender                         defender
# 16  17                poker tournaments                poker tournaments
# 5    6                              kcs                              kcs
#
#     mean_health_score  median_health_score  mean_medical_score  \
# 3            226.5945             226.5945             24.5363
# 29           203.9913             203.9913            243.6227
# 25           168.4160             130.3137            198.0859
# 33           114.1950             114.1950            194.8462
# 2             74.7692              74.7692             22.8042
# 8             57.5809              75.1587             49.4786
# 6             56.5040              44.4720             55.5602
# 49            44.3673              44.3673             78.6086
# 45            35.2337               1.1535             46.1671
# 37            27.9989              38.0222            119.2782
# 18            23.1269              23.1269             83.3028
# 10            22.5833              18.3837             57.1493
# 15            20.1810              14.9945             39.9599
# 0             17.3931              10.2143             28.3937
# 43            17.2940              16.4337             36.5626
# 32            14.7771              14.7771             32.5055
# 40            13.9195              12.3219             13.8007
# 14            11.6742              11.6742              5.5440
# 1             10.4784               7.7701             16.4415
# 41            10.2074               6.5388             18.7398
# 42             8.8980               2.9900             12.3074
# 23             7.4336               7.4336            204.5207
# 12             7.1708               7.1708             66.2089
# 11             4.5480               4.5480              4.3716
# 47             4.4472               4.4472             24.4462
# 48             3.9968               3.9968             52.7193
# 28             2.8709               1.0395             57.1064
# 17             2.8128               0.3303             26.0799
# 44             2.4109               2.4109             43.2100
# 9              2.2672               2.2672             37.0891
# 31             2.0071               1.3135             29.1524
# 13             1.6772               1.6772              9.7717
# 35             1.5202               1.5202            162.8659
# 4              1.1339               1.1339              4.0976
# 24             0.9195               0.9195              2.3739
# 46             0.6762               0.6762             56.6894
# 21             0.3939               0.3939              0.5514
# 38             0.2791               0.2791              0.3598
# 39             0.0000               0.0000              0.0000
# 7              0.0000               0.0000            231.0034
# 36             0.0000               0.0000              0.8015
# 34             0.0000               0.0000              0.4462
# 30             0.0000               0.0000              0.0893
# 27             0.0000               0.0000              0.0000
# 26             0.0000               0.0000              0.3505
# 22             0.0000               0.0000              2.0731
# 20             0.0000               0.0000              0.4028
# 19             0.0000               0.0000              0.6087
# 16             0.0000               0.0000              0.9231
# 5              0.0000               0.0000            192.6268
#
#     median_medical_score
# 3                24.5363
# 29              243.6227
# 25              184.8707
# 33              194.8462
# 2                22.8042
# 8                32.9048
# 6                23.8385
# 49               78.6086
# 45                8.7453
# 37               93.8006
# 18               83.3028
# 10               75.9148
# 15               29.2368
# 0                41.8619
# 43               32.4568
# 32               32.5055
# 40               10.9814
# 14                5.5440
# 1                 5.8377
# 41               22.1102
# 42                2.8687
# 23              204.5207
# 12               66.2089
# 11                4.3716
# 47               24.4462
# 48               52.7193
# 28                1.5486
# 17               14.1282
# 44               43.2100
# 9                37.0891
# 31                4.9398
# 13                9.7717
# 35              162.8659
# 4                 4.0976
# 24                2.3739
# 46               56.6894
# 21                0.5514
# 38                0.3598
# 39                0.0000
# 7               231.0034
# 36                0.8015
# 34                0.4462
# 30                0.0893
# 27                0.0000
# 26                0.3505
# 22                2.0731
# 20                0.4028
# 19                0.6087
# 16                0.9231
# 5               192.6268
